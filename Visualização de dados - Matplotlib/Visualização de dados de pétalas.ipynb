# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dados = pd.read_csv('Dados/iris.csv')

# %%
dados.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# Scatter-plot

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da Sépala', fontsize=15)
eixo.set_ylabel('Largura da Sépala', fontsize=15)
# Out:
# Text(0, 0.5, 'Largura da Sépala')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da Sépala', fontsize=15)
eixo.set_ylabel('Largura da Sépala', fontsize=15)
eixo.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r',
        'Iris-versicolor': 'b',
        'Iris-virginica': 'g'}

for especie in dados['espécie'].unique():
    tmp = dados[dados['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                color=cores[especie])

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da Sépala', fontsize=15)
eixo.set_ylabel('Largura da Sépala', fontsize=15)
eixo.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r',
        'Iris-versicolor': 'b',
        'Iris-virginica': 'g'}

for especie in dados['espécie'].unique():
    tmp = dados[dados['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                color=cores[especie])

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da Sépala', fontsize=15)
eixo.set_ylabel('Largura da Sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r',
        'Iris-versicolor': 'b',
        'Iris-virginica': 'g'}
marcadores = {'Iris-setosa':'x',
        'Iris-versicolor': 'o',
        'Iris-virginica': 'v'}

for especie in dados['espécie'].unique():
    tmp = dados[dados['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                color=cores[especie], marker=marcadores[especie],
                s=100)

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da Sépala', fontsize=15)
eixo.set_ylabel('Largura da Sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20)

# %% [markdown]
# Box-plot

# %%
fig =plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados['largura_pétala'])
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(1, 0, 'largura_pétala')]

# %%
fig =plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop('espécie', axis=1).values)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig =plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig =plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'b', 'orange', 'g']

caixas = eixo.boxplot(dados.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)

# %%
fig =plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'b', 'orange', 'g']

caixas = eixo.boxplot(dados.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)
    
for outlier in caixas['fliers']:
    outlier.set(marker='x', markersize=8)

# %%
a = ("John", "Charles", "Mike")
b = ("Jenny", "Christy", "Monica")

x = zip(a, b)
print(list(x))
# Out:
# [('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica')]

# %% [markdown]
# Histograma

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'])
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'], bins=20, orientation='horizontal')
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(dados['comprimento_pétala'], bins=20, density=True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
             xy=(4.5,20), fontsize=20)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
             xy=(4.5,20), fontsize=20)

eixo.axvline(mu, color='red', linestyle='--')
eixo.annotate('Média', xy=(mu-0.8, 28), fontsize=20)

eixo.axvline(dados['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('Mediana', xy=(dados['comprimento_pétala'].median(),31), fontsize=20)
# Out:
# Text(4.35, 31, 'Mediana')

# %% [markdown]
# Aprensentando os símbolos de mu e sigma com \ antes do nome no primeiro eixo.annotate

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = dados['comprimento_pétala'].mean(), dados['comprimento_pétala'].std()

eixo.hist(dados['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy=(4.5,20), fontsize=20)

eixo.axvline(mu, color='red', linestyle='--')
eixo.annotate('Média', xy=(mu-0.8, 28), fontsize=20)

eixo.axvline(dados['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('Mediana', xy=(dados['comprimento_pétala'].median() + 0.1, 31), fontsize=20)
# Out:
# Text(4.449999999999999, 31, 'Mediana')

# %% [markdown]
# Distribuições para cada espécie

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

dados_iv = dados[dados['espécie'] == 'Iris-versicolor']

mu, sigma = dados_iv['comprimento_pétala'].mean(), dados_iv['comprimento_pétala'].std()

eixo.hist(dados_iv['comprimento_pétala'], bins=20)
eixo.set_title('Iris-versicolor', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy=(4.6, 6), fontsize=20)

eixo.axvline(mu, color='red', linestyle='--')
eixo.annotate('Média', xy=(mu-0.5, 5.5), fontsize=20)

eixo.axvline(dados_iv['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('Mediana', xy=(dados_iv['comprimento_pétala'].median() - 0.7, 6.5), fontsize=20)

fig.savefig('histograma_iv', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

dados_is = dados[dados['espécie'] == 'Iris-setosa']

mu, sigma = dados_is['comprimento_pétala'].mean(), dados_is['comprimento_pétala'].std()

eixo.hist(dados_is['comprimento_pétala'], bins=20)
eixo.set_title('Iris-setosa', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy=(1.7, 7), fontsize=20)

eixo.axvline(mu, color='red', linestyle='--')
eixo.annotate('Média', xy=(mu-0.2, 13.5), fontsize=20)

eixo.axvline(dados_is['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('Mediana', xy=(dados_is['comprimento_pétala'].median() + 0.05, 12), fontsize=20)

fig.savefig('histograma_is', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

dados_ivg = dados[dados['espécie'] == 'Iris-virginica']

mu, sigma = dados_ivg['comprimento_pétala'].mean(), dados_ivg['comprimento_pétala'].std()

eixo.hist(dados_ivg['comprimento_pétala'], bins=20)
eixo.set_title('Iris-virginica', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy=(6.3, 7), fontsize=20)

eixo.axvline(mu, color='red', linestyle='--')
eixo.annotate('Média', xy=(mu, 8), fontsize=20)

eixo.axvline(dados_ivg['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('Mediana', xy=(dados_ivg['comprimento_pétala'].median(), 7), fontsize=20)

fig.savefig('histograma_ivg', bbox_inches='tight')

# %% [markdown]
# Apresentando os três últimos gráficos em uma mesma figura

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivg.png').size
combinada = Image.new('RGB', (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_iv.png','histograma_is.png',
                               'histograma_ivg.png']):
    combinada.paste(imagem, (intervalo, 0))
    intervalo += largura

combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1179x361 at 0x1E5EE74AFA0>
