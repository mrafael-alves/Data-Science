# %%
import pandas as pd

# %%
json = open('dados/aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_jason = pd.read_json('dados/aluguel.json')
df_jason
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
txt = open('dados/aluguel.txt')
print(txt.read())
# Out:
# Tipo	Bairro	Quartos	Vagas	Suites	Area	Valor	Condominio	IPTU
# Quitinete	Copacabana	1	0	0	40	1700	500	60
# Casa	Jardim BotÃ¢nico	2	0	1	100	7000
# Conjunto Comercial/Sala	Barra da Tijuca	0	4	0	150	5200	4020	1111
# Apartamento	Centro	1	0	0	15	800	390	20
# Apartamento	HigienÃ³polis	1	0	0	48	800	230
# Apartamento	Vista Alegre	3	1	0	70	1200
# Apartamento	Cachambi	2	0	0	50	1300	301	17
# Casa de CondomÃ­nio	Barra da Tijuca	5	4	5	750	22000
# Casa de CondomÃ­nio	Ramos	2	2	0	65	1000
# Conjunto Comercial/Sala	Centro	0	3	0	695	35000	19193	3030

# %%
df_txt = pd.read_table('dados/aluguel.txt')
df_txt
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_xlsx = pd.read_excel('dados/aluguel.xlsx')
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_html1 = pd.read_html('dados/dados_html_1.html')
df_html1[0]
# Out:
#   FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
# 0      00 A 18               R$218,99           R$192,60    R$334,48
# 1      19 A 23               R$263,63           R$207,67    R$380,06
# 2      24 A 28               R$322,44           R$224,26    R$464,39
# 3      29 A 33               R$402,05           R$258,63    R$566,68
# 4      34 A 38               R$455,17           R$306,37    R$664,61
# 5      39 A 43               R$489,29           R$417,93    R$742,72
# 6      44 A 48               R$582,65           R$495,24    R$869,47
# 7      49 A 53               R$718,86           R$562,64  R$1.046,29
# 8      54 A 58               R$908,54           R$721,00  R$1.355,74
# 9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53

# %%
df_url = pd.read_html('https://unafiscosaude.org.br/site/descricao-dos-planos-unafisco-saude/')
df_html1[0]
# Out:
#   Faixa Etária UNAFISCO SAÚDE SOFT II Valor final com Auxílio-saúde
# 0      00 a 18              R$ 264,75                     R$ 163,20
# 1      19 a 23              R$ 318,75                     R$ 215,78
# 2      24 a 28              R$ 389,85                     R$ 284,78
# 3      29 a 33              R$ 486,11                     R$ 380,32
# 4      34 a 38              R$ 550,33                     R$ 439,61
# 5      39 a 43              R$ 591,57                     R$ 475,20
# 6      44 a 48              R$ 704,46                     R$ 587,04
# 7      49 a 53              R$ 869,16                     R$ 749,89
# 8      54 a 58            R$ 1.098,48                     R$ 977,35
# 9   59 ou mais            R$ 1.504,70                   R$ 1.380,37

# %%
df_url2 = pd.read_html('https://www.federalreserve.gov/releases/h3/20170302/')

# %%
len(df_url2)
# Out:
# 5

# %%
df_url2[0]
# Out:
#                                                    0   1  \
# 0  What's New · What's Next · Site Map · A-Z Inde... NaN
#
#                         2   3
# 0  Search Advanced Search NaN

# %%
df_url2[1]
# Out:
#               0             1               2                               3  \
# 0  Aboutthe Fed  News& Events  MonetaryPolicy  BankingInformation& Regulation
#
#                 4                       5                     6  \
# 0  PaymentSystems  EconomicResearch& Data  Consumer Information
#
#                       7               8             9
# 0  CommunityDevelopment  ReportingForms  Publications

# %%
df_url2[2]
# Out:
#    Table 1 Not seasonally adjusted. Millions of dollars unless otherwise noted.  \
#                                                                            Date
#                                                                            Date
# 0                                             Month 7
# 1                                           Feb. 2016
# 2                                           Mar. 2016
# 3                                           Apr. 2016
# 4                                            May 2016
# 5                                           June 2016
# 6                                           July 2016
# 7                                           Aug. 2016
# 8                                          Sept. 2016
# 9                                           Oct. 2016
# 10                                          Nov. 2016
# 11                                          Dec. 2016
# 12                                          Jan. 2017
# ...

# %%
df_url2[3]
# Out:
#    Table 2 Not seasonally adjusted. Millions of dollars.                      \
#                                                     Date            Reserves
#                                                     Date             Total 1
# 0                                             Month 7                Month 7
# 1                                           Feb. 2016                2510850
# 2                                           Mar. 2016                2519685
# 3                                           Apr. 2016                2487012
# 4                                            May 2016                2443789
# 5                                           June 2016                2427479
# 6                                           July 2016                2371183
# 7                                           Aug. 2016                2413530
# 8                                          Sept. 2016                2325108
# ...

# %%
df_url2[4]
# Out:
#    Table 3 Not seasonally adjusted. Millions of dollars.  \
#                                                     Date
#                                                     Date
# 0                                             Month 2
# 1                                           Feb. 2016
# 2                                           Mar. 2016
# 3                                           Apr. 2016
# 4                                            May 2016
# 5                                           June 2016
# 6                                           July 2016
# 7                                           Aug. 2016
# 8                                          Sept. 2016
# 9                                           Oct. 2016
# 10                                          Nov. 2016
# 11                                          Dec. 2016
# 12                                          Jan. 2017
# 13                                          Feb. 2017
# ...

# %%
df_html2 = pd.read_html('dados/dados_html_2.html')

# %%
len(df_html2)
# Out:
# 3

# %%
df_html2[0]
# Out:
#                   Date      Reserve balances required  \
#                   Date Reserve balance requirements 1
# 0              Month 7                        Month 7
# 1            Apr. 2017                         113224
# 2             May 2017                         115464
# 3            June 2017                         118187
# 4            July 2017                         120636
# 5            Aug. 2017                         120091
# 6           Sept. 2017                         122109
# 7            Oct. 2017                         116873
# 8            Nov. 2017                         123141
# 9            Dec. 2017                         123720
# 10           Jan. 2018                         126792
# 11           Feb. 2018                         124006
# 12           Mar. 2018                         120285
# 13           Apr. 2018                         126415
# 14                 NaN                            NaN
# ...

# %%
df_html2[1]
# Out:
#                   Date            Reserves                      \
#                   Date             Total 1            Required
# 0              Month 7             Month 7             Month 7
# 1            Apr. 2017             2344812              176616
# 2             May 2017             2288936              178630
# 3            June 2017             2269683              181324
# 4            July 2017             2296929              184242
# 5            Aug. 2017             2407173              183249
# 6           Sept. 2017             2357875              184248
# 7            Oct. 2017             2310902              182074
# 8            Nov. 2017             2378282              186968
# 9            Dec. 2017             2309823              189269
# 10           Jan. 2018             2281018              193209
# 11           Feb. 2018             2305256              190487
# 12           Mar. 2018             2230875              184151
# ...

# %%
df_html2[2]
# Out:
#                   Date Borrowings from the Federal Reserve  \
#                   Date                               Total
# 0              Month 2                             Month 2
# 1            Apr. 2017                                  45
# 2             May 2017                                  56
# 3            June 2017                                  95
# 4            July 2017                                 166
# 5            Aug. 2017                                 220
# 6           Sept. 2017                                 224
# 7            Oct. 2017                                 151
# 8            Nov. 2017                                  65
# 9            Dec. 2017                                  75
# 10           Jan. 2018                                  58
# 11           Feb. 2018                                  20
# 12           Mar. 2018                                  16
# 13           Apr. 2018                                  51
# ...

# %%
type(df_html1)
# Out:
# list

# %%
df_html2[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   (Date, Date)                                                    20 non-null     object
#  1   (Borrowings from the Federal Reserve, Total)                    20 non-null     object
#  2   (Borrowings from the Federal Reserve, Primary)                  20 non-null     object
#  3   (Borrowings from the Federal Reserve, Secondary)                20 non-null     object
#  4   (Borrowings from the Federal Reserve, Seasonal)                 20 non-null     object
#  5   (Borrowings from the Federal Reserve, Other credit extensions)  20 non-null     object
#  6   (Nonborrowed reserves 1, Nonborrowed reserves 1)                20 non-null     object
# dtypes: object(7)
# memory usage: 1.3+ KB

# %%
df_html2[2].shape
# Out:
# (21, 7)

# %%
df_html2[2].columns
# Out:
# MultiIndex([(                               'Date',                    'Date'),
#             ('Borrowings from the Federal Reserve',                   'Total'),
#             ('Borrowings from the Federal Reserve',                 'Primary'),
#             ('Borrowings from the Federal Reserve',               'Secondary'),
#             ('Borrowings from the Federal Reserve',                'Seasonal'),
#             ('Borrowings from the Federal Reserve', 'Other credit extensions'),
#             (             'Nonborrowed reserves 1',  'Nonborrowed reserves 1')],
#            )
